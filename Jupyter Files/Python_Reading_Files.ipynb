# %%
f = open("sample-text-file.txt", "w+")
f.write(" My name is rahul ")
f.close()

# %%
f = open("sample-file-2.txt", "w+")

for i in range(10):
  f.write("This is line %d\r\n" % (i+1))
f.close()

# %%
f = open("sample-file-2.txt","r")

if f.mode == 'r':
  contents = f.read()
  print(contents)
f.close()
# Out:
# This is line 1
# This is line 2
# This is line 3
# This is line 4
# This is line 5
# This is line 6
# This is line 7
# This is line 8
# This is line 9
# This is line 10

# %%
try:
  f = open("sample-text-file.txt","r")
  #f.write("My name is rahul")
  f.close()
except Exception as e:
  print(e)
else:
  print("File Created Successfully.")
# Out:
# File Created Successfully.

# %%
import pandas as pd

f = "Rs12043.xlsx"

xl = pd.ExcelFile(f)

print(xl.sheet_names)
df1 = xl.parse('Sheet1')
df2 = xl.parse('Sheet2')

display(df1,df2)
# Out:
# ['Sheet1', 'Sheet2']
#     Name  Age    City
# 0  Rahul   18  Indore
# 1  Rohit   17  Bhopal
# Empty DataFrame
# Columns: []
# Index: []

# %%
import pandas as pd
import openpyxl

df = pd.DataFrame([[11,21,31],[12,22,32],[31,32,33]],index=["One","Two","Three"],columns=['a','b','c'])
print(df)

df.to_excel("pandas_to_excel.xlsx")
# Out:
#         a   b   c
# One    11  21  31
# Two    12  22  32
# Three  31  32  33

# %%
import pandas as pd


f = pd.read_csv("/content/pandas_to_excel.csv")
display(f)
# Out:
#    Unnamed: 0   0   1   2
# 0           0  11  21  31
# 1           1  12  22  32
# 2           2  31  32  33

# %%
import pandas as pd
import openpyxl

df = pd.DataFrame([[11,21,31],[12,22,32],[31,32,33]],index=["One","Two","Three"],columns=['a','b','c'])
print(df)

df.to_csv("pandas_to_csv.csv")
df.to_csv("pandas_to_csv_without.csv",index=False,header=False)
# Out:
#         a   b   c
# One    11  21  31
# Two    12  22  32
# Three  31  32  33

# %%
name = "rahul"

f = open(f"{name}.txt", "w+")
print(f"{name}")
f.write(f" My name is {name}")
f.close()
# Out:
# rahul
